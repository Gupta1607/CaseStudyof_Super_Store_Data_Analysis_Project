# %% [markdown]
# # Data Analysis of Superstore

# %% [markdown]
# ### Import files

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Importing  Dataset

# %%
store_df=pd.read_csv("Analysis of Super Store - DA.csv")

# %%
store_df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
## Head of the Dataset 
store_df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
# Drop a Column Postal Code 
store_df.drop(columns="Postal Code",inplace=True)

# %%
store_df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   Region         Category Sub-Category     Sales  Quantity  Discount    Profit
# 0  South        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1  South        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2   West  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3  South        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  South  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %%
## Understanding Numerical Features in Data Set
store_df.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
# Size of Dataset
store_df.shape
# Out:
# (9994, 12)

# %%
# Information of Dataset
store_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Region        9994 non-null   object
#  6   Category      9994 non-null   object
#  7   Sub-Category  9994 non-null   object
#  8   Sales         9994 non-null   float64
#  9   Quantity      9994 non-null   int64
#  10  Discount      9994 non-null   float64
#  11  Profit        9994 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 937.1+ KB

# %%
store_df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State Region  \
# 9989    Second Class  Consumer  United States        Miami     Florida  South
# 9990  Standard Class  Consumer  United States   Costa Mesa  California   West
# 9991  Standard Class  Consumer  United States   Costa Mesa  California   West
# 9992  Standard Class  Consumer  United States   Costa Mesa  California   West
# 9993    Second Class  Consumer  United States  Westminster  California   West
#
#              Category Sub-Category    Sales  Quantity  Discount   Profit
# 9989        Furniture  Furnishings   25.248         3       0.2   4.1028
# 9990        Furniture  Furnishings   91.960         2       0.0  15.6332
# 9991       Technology       Phones  258.576         2       0.2  19.3932
# 9992  Office Supplies        Paper   29.600         4       0.0  13.3200
# 9993  Office Supplies   Appliances  243.160         2       0.0  72.9480

# %%
print(store_df["Ship Mode"].unique())
print(store_df["Segment"].unique())
print(store_df["Country"].unique())
print(store_df["City"].unique())
print(store_df["State"].unique())
print(store_df["Region"].unique())
print(store_df["Category"].unique())
print(store_df["Sub-Category"].unique())
print(store_df["Sales"].unique())
print(store_df["Profit"].unique())
print(store_df["Discount"].unique())
print(store_df["Quantity"].unique())
# Out:
# ['Second Class' 'Standard Class' 'First Class' 'Same Day']
# ['Consumer' 'Corporate' 'Home Office']
# ['United States']
# ['Henderson' 'Los Angeles' 'Fort Lauderdale' 'Concord' 'Seattle'
#  'Fort Worth' 'Madison' 'West Jordan' 'San Francisco' 'Fremont'
#  'Philadelphia' 'Orem' 'Houston' 'Richardson' 'Naperville' 'Melbourne'
#  'Eagan' 'Westland' 'Dover' 'New Albany' 'New York City' 'Troy' 'Chicago'
#  'Gilbert' 'Springfield' 'Jackson' 'Memphis' 'Decatur' 'Durham' 'Columbia'
#  'Rochester' 'Minneapolis' 'Portland' 'Saint Paul' 'Aurora' 'Charlotte'
#  'Orland Park' 'Urbandale' 'Columbus' 'Bristol' 'Wilmington' 'Bloomington'
#  'Phoenix' 'Roseville' 'Independence' 'Pasadena' 'Newark' 'Franklin'
#  'Scottsdale' 'San Jose' 'Edmond' 'Carlsbad' 'San Antonio' 'Monroe'
#  'Fairfield' 'Grand Prairie' 'Redlands' 'Hamilton' 'Westfield' 'Akron'
#  'Denver' 'Dallas' 'Whittier' 'Saginaw' 'Medina' 'Dublin' 'Detroit'
#  'Tampa' 'Santa Clara' 'Lakeville' 'San Diego' 'Brentwood' 'Chapel Hill'
# ...

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### 1.Missing Value

# %%
# is there null value in dataset or no
missing_value_count=store_df.isnull().sum()

# %%
missing_value_count[0:10]
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# dtype: int64

# %% [markdown]
# #### 2.Duplicate Value

# %%
## Checking For Duplicated Rows in Data
store_df.duplicated().sum()
# Out:
# 50

# %%
## To Remove Duplicate row form Data
store_df.drop_duplicates(inplace=True)

# %%
store_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Exploratory data analysis (EDA)

# %%
store_cat = [f for f in store_df.columns if(store_df[f].dtype=='O')]
store_df[store_cat].describe()
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9944      9944           9944           9944        9944
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5930      5160           9944            906        1980
#
#        Region         Category Sub-Category
# count    9944             9944         9944
# unique      4                3           17
# top      West  Office Supplies      Binders
# freq     3177             5986         1518

# %%
for c in store_cat:
    print(c , ":" ,store_df[c].nunique())
# Out:
# Ship Mode : 4
# Segment : 3
# Country : 1
# City : 531
# State : 49
# Region : 4
# Category : 3
# Sub-Category : 17

# %%
def Viz_Bar(df1 , cx , cy ,t='',rot="horizontal" , x=True ):
    if(x is False):
        plt.rcdefaults()
        fig, ax = plt.subplots()
        ax.barh(df1.head(10)[cx], df1.head(10)[cy], align='center', color=['#F05454','#30475E' ,'#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'] )
        ax.set_yticks(df1.head(10)[cx], labels=df1.head(10)[cx])
        ax.invert_yaxis()  # labels read top-to-bottom
        ax.set_xlabel(cy)
        ax.set_title(t)
        plt.xticks(rotation = rot)
        plt.show()
    else :
        plt.bar(df1.head(10)[cx] ,df1.head(10)[cy] ,  color=['#F05454','#30475E' ,'#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'] )
        plt.xlabel(cx)
        plt.ylabel(cy)
        plt.title(t)
        plt.xticks(rotation = rot)
        plt.show()

# %% [markdown]
# #### Ship Mode Analysis

# %% [markdown]
# Ship Mode Sales

# %%
store_df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    5930
# Second Class      1941
# First Class       1531
# Same Day           542
# Name: count, dtype: int64

# %% [markdown]
# Relationship between Segment and Ship Mode

# %%
pivot_table = store_df.pivot_table(index = "Segment" ,columns="Ship Mode" ,values='Sales' , aggfunc = 'sum')
pivot_table
# Out:
# Ship Mode    First Class   Same Day  Second Class  Standard Class
# Segment
# Consumer     159055.8770  60596.359   231432.9816     708332.2964
# Corporate    105817.7659  45121.323   146122.4748     408908.6311
# Home Office   86400.9880  22604.043    81568.5810     238638.0565

# %%
pivot_table.plot(kind = 'bar'  ,stacked = False)
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
store_df.groupby("Ship Mode")["Sales"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Sales'>

# %% [markdown]
# Ship Mode Profit

# %%
pivot_table2 = store_df.pivot_table(index = "Segment" ,columns="Ship Mode" ,values='Profit' , aggfunc = 'sum')
pivot_table2
# Out:
# Ship Mode    First Class   Same Day  Second Class  Standard Class
# Segment
# Consumer      21332.4618  9874.2054    24919.6104      77813.2442
# Corporate     14446.6620  1818.1418    18231.9501      57414.4067
# Home Office   13131.3239  4179.5397    14274.0111      28662.0008

# %%
pivot_table2.plot(kind = 'bar'  ,stacked = False)
plt.ylabel("Profit")
# Out:
# Text(0, 0.5, 'Profit')

# %%
store_df.groupby("Ship Mode")["Profit"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Profit'>

# %% [markdown]
# Its Concluded That Most the Sales & Profit Comes from Customers Who Use Standard Class Ship Mode .

# %% [markdown]
# #### Segments Analysis

# %%
segments_info = store_df.groupby("Segment").sum().reset_index()
segments_info
# Out:
#        Segment                                          Ship Mode  \
# 0     Consumer  Second ClassSecond ClassStandard ClassStandard...
# 1    Corporate  Second ClassStandard ClassStandard ClassFirst ...
# 2  Home Office  Standard ClassStandard ClassSecond ClassStanda...
#
#                                              Country  \
# 0  United StatesUnited StatesUnited StatesUnited ...
# 1  United StatesUnited StatesUnited StatesUnited ...
# 2  United StatesUnited StatesUnited StatesUnited ...
#
#                                                 City  \
# 0  HendersonHendersonFort LauderdaleFort Lauderda...
# 1  Los AngelesFremontFremontRichardsonRichardsonN...
# 2  Fort WorthFort WorthHoustonHoustonHoustonHoust...
#
#                                                State  \
# 0  KentuckyKentuckyFloridaFloridaCaliforniaCalifo...
# 1  CaliforniaNebraskaNebraskaTexasTexasIllinoisCa...
# 2  TexasTexasTexasTexasTexasTexasTexasIllinoisIll...
#
# ...

# %% [markdown]
# Segment Sales

# %%
segments_info[['Segment' , 'Sales']]
# Out:
#        Segment         Sales
# 0     Consumer  1.159418e+06
# 1    Corporate  7.059702e+05
# 2  Home Office  4.292117e+05

# %%
Viz_Bar(segments_info , 'Segment' ,'Sales')

# %%
store_df.groupby("Segment")["Sales"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Sales'>

# %% [markdown]
# Segment Profit

# %%
segments_info[['Segment' , 'Profit']]
# Out:
#        Segment       Profit
# 0     Consumer  133939.5218
# 1    Corporate   91911.1606
# 2  Home Office   60246.8755

# %%
Viz_Bar(segments_info , 'Segment' ,'Profit')

# %%
store_df.groupby("Segment")["Profit"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Profit'>

# %% [markdown]
# Its Observed That Consumer Segment is the Most Important Segment as It has the Highest Sales & Profit.

# %% [markdown]
# #### City Analysis

# %%
store_df["City"].value_counts()
# Out:
# City
# New York City      906
# Los Angeles        734
# Philadelphia       531
# San Francisco      503
# Seattle            424
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: count, Length: 531, dtype: int64

# %%
cities_info = store_df.groupby("City").sum().reset_index()
cities_info
# Out:
#             City                                          Ship Mode  \
# 0       Aberdeen                                       Second Class
# 1        Abilene                                        First Class
# 2          Akron  Standard ClassStandard ClassStandard ClassSeco...
# 3    Albuquerque  Standard ClassStandard ClassSecond ClassSecond...
# 4     Alexandria  Standard ClassStandard ClassStandard ClassStan...
# ..           ...                                                ...
# 526   Woonsocket   Second ClassStandard ClassFirst ClassFirst Class
# 527      Yonkers  Standard ClassStandard ClassStandard ClassStan...
# 528         York  Standard ClassStandard ClassStandard ClassStan...
# 529      Yucaipa                                     Standard Class
# 530         Yuma         Same DaySame DayStandard ClassSecond Class
#
#                                                Segment  \
# 0                                             Consumer
# ...

# %% [markdown]
# Highest Selling Cities

# %%
cities_info[['City' ,'Sales']].sort_values(by = ["Sales"] ,ascending = False).head(10)
# Out:
#               City        Sales
# 329  New York City  255841.1050
# 266    Los Angeles  175296.8170
# 452        Seattle  119460.2820
# 438  San Francisco  112184.8130
# 374   Philadelphia  108948.1090
# 207        Houston   64422.7704
# 80         Chicago   48500.8090
# 437      San Diego   47502.1290
# 216   Jacksonville   44713.1830
# 464    Springfield   43054.3420

# %%
Viz_Bar(cities_info.sort_values(by=["Sales"],ascending=False), 'City' , 'Sales' , 'TOP 10 SELLING CITIES' , 'horizontal',False)

# %% [markdown]
# Lowest Selling Cities

# %%
cities_info[['City' ,'Sales']].sort_values(by = ["Sales"] ,ascending = True).head(10)
# Out:
#                 City  Sales
# 1            Abilene  1.392
# 140           Elyria  1.824
# 221          Jupiter  2.064
# 370        Pensacola  2.214
# 354     Ormond Beach  2.808
# 441  San Luis Obispo  3.620
# 463       Springdale  4.300
# 249           Layton  4.960
# 222           Keller  6.000
# 305    Missouri City  6.370

# %% [markdown]
# Highest Profitable Cities

# %%
cities_info[['City' ,'Profit']].sort_values(by = ["Profit"] ,ascending = False).head(10)
# Out:
#               City      Profit
# 329  New York City  62004.5903
# 266    Los Angeles  30308.4841
# 452        Seattle  29121.6825
# 438  San Francisco  17482.9366
# 123        Detroit  13146.6935
# 233      Lafayette  10018.3876
# 215        Jackson   7581.6828
# 21         Atlanta   6993.6629
# 300    Minneapolis   6824.5846
# 437      San Diego   6368.5020

# %%
Viz_Bar(cities_info[['City' ,'Profit']].sort_values(by = ["Profit"] ,ascending = False) , 'City' , 'Profit' ,'TOP 10 PROFITABLE CITIES' , 'horizontal',False)

# %% [markdown]
# Lowest Profitable Cities

# %%
cities_info[cities_info['Profit']<=0].sort_values(by = ['Profit'])
# Out:
#              City                                          Ship Mode  \
# 374  Philadelphia  Second ClassStandard ClassStandard ClassStanda...
# 207       Houston  Second ClassStandard ClassStandard ClassStanda...
# 434   San Antonio  Standard ClassStandard ClassStandard ClassStan...
# 241     Lancaster  Second ClassStandard ClassStandard ClassSecond...
# 80        Chicago  Standard ClassFirst ClassStandard ClassStandar...
# ..            ...                                                ...
# 354  Ormond Beach                                     Standard Class
# 370     Pensacola                                        First Class
# 140        Elyria                                       Second Class
# 7         Altoona                             First ClassFirst Class
# 198       Hickory                             Same DayStandard Class
#
#                                                Segment  \
# 374  ConsumerConsumerConsumerConsumerConsumerConsum...
# ...

# %% [markdown]
# We Have 116 City Branches That are making Negative Profit.

# %% [markdown]
# #### State Analysis

# %%
store_df["State"].value_counts()
# Out:
# State
# California              1980
# New York                1119
# Texas                    980
# Pennsylvania             581
# Washington               502
# Illinois                 490
# Ohio                     468
# Florida                  383
# Michigan                 254
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   123
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
states_info = store_df.groupby('State').sum().reset_index()
states_info.head()
# Out:
#         State                                          Ship Mode  \
# 0     Alabama  First ClassFirst ClassSecond ClassSecond Class...
# 1     Arizona  Standard ClassStandard ClassStandard ClassStan...
# 2    Arkansas  Standard ClassStandard ClassStandard ClassStan...
# 3  California  Second ClassStandard ClassStandard ClassStanda...
# 4    Colorado  Standard ClassStandard ClassStandard ClassFirs...
#
#                                              Segment  \
# 0  CorporateCorporateConsumerConsumerConsumerCons...
# 1  CorporateCorporateConsumerConsumerHome OfficeH...
# 2  ConsumerHome OfficeConsumerConsumerConsumerCon...
# 3  CorporateConsumerConsumerConsumerConsumerConsu...
# 4  ConsumerConsumerConsumerConsumerConsumerCorpor...
#
#                                              Country  \
# 0  United StatesUnited StatesUnited StatesUnited ...
# 1  United StatesUnited StatesUnited StatesUnited ...
# 2  United StatesUnited StatesUnited StatesUnited ...
# ...

# %% [markdown]
# States Sales

# %%
states_info = states_info.sort_values(by = ['Sales'] , ascending = False)
states_info.head(10)
# Out:
#            State                                          Ship Mode  \
# 3     California  Second ClassStandard ClassStandard ClassStanda...
# 30      New York  Standard ClassStandard ClassFirst ClassFirst C...
# 41         Texas  Standard ClassStandard ClassSecond ClassFirst ...
# 45    Washington  Standard ClassStandard ClassStandard ClassSeco...
# 36  Pennsylvania  Second ClassStandard ClassStandard ClassStanda...
# 8        Florida  Standard ClassStandard ClassStandard ClassStan...
# 11      Illinois  Standard ClassStandard ClassFirst ClassStandar...
# 33          Ohio  Second ClassSecond ClassSecond ClassSecond Cla...
# 20      Michigan  Second ClassSecond ClassStandard ClassStandard...
# 44      Virginia  First ClassFirst ClassSecond ClassSecond Class...
#
#                                               Segment  \
# 3   CorporateConsumerConsumerConsumerConsumerConsu...
# 30  CorporateCorporateConsumerConsumerConsumerCons...
# ...

# %%
colors = color=['#F05454','#30475E' ,'#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
store_df.groupby('State')['Sales'].sum().sort_values(ascending=True).tail(20).plot.barh(color=colors)
# Out:
# <Axes: ylabel='State'>

# %% [markdown]
# States Profit

# %%
states_info = states_info.sort_values(by = ['Profit'] , ascending = False)
states_info.head()
# Out:
#          State                                          Ship Mode  \
# 3   California  Second ClassStandard ClassStandard ClassStanda...
# 30    New York  Standard ClassStandard ClassFirst ClassFirst C...
# 45  Washington  Standard ClassStandard ClassStandard ClassSeco...
# 20    Michigan  Second ClassSecond ClassStandard ClassStandard...
# 44    Virginia  First ClassFirst ClassSecond ClassSecond Class...
#
#                                               Segment  \
# 3   CorporateConsumerConsumerConsumerConsumerConsu...
# 30  CorporateCorporateConsumerConsumerConsumerCons...
# 45  ConsumerConsumerHome OfficeConsumerConsumerCon...
# 20  ConsumerConsumerConsumerConsumerConsumerConsum...
# 44  ConsumerConsumerConsumerConsumerConsumerConsum...
#
#                                               Country  \
# 3   United StatesUnited StatesUnited StatesUnited ...
# 30  United StatesUnited StatesUnited StatesUnited ...
# 45  United StatesUnited StatesUnited StatesUnited ...
# ...

# %%
color=['#F05454','#30475E' ,'#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
store_df.groupby('State')['Profit'].sum().sort_values(ascending=True).tail(20).plot.barh(color=colors)
# Out:
# <Axes: ylabel='State'>

# %% [markdown]
# The Two Important States are New York and California , New York is more profitable than California

# %% [markdown]
# Non Profitable States

# %%
states_info[states_info['Profit']<=0]
# Out:
#              State                                          Ship Mode  \
# 35          Oregon  Standard ClassStandard ClassStandard ClassStan...
# 8          Florida  Standard ClassStandard ClassStandard ClassStan...
# 1          Arizona  Standard ClassStandard ClassStandard ClassStan...
# 40       Tennessee  Standard ClassStandard ClassStandard ClassStan...
# 4         Colorado  Standard ClassStandard ClassStandard ClassFirs...
# 31  North Carolina  Standard ClassStandard ClassStandard ClassStan...
# 11        Illinois  Standard ClassStandard ClassFirst ClassStandar...
# 36    Pennsylvania  Second ClassStandard ClassStandard ClassStanda...
# 33            Ohio  Second ClassSecond ClassSecond ClassSecond Cla...
# 41           Texas  Standard ClassStandard ClassSecond ClassFirst ...
#
#                                               Segment  \
# 35  Home OfficeConsumerConsumerConsumerConsumerCon...
# 8   ConsumerConsumerCorporateHome OfficeHome Offic...
# ...

# %% [markdown]
# We Have 41 States in Branches That do not have any profit margin

# %% [markdown]
# #### Region Analysis

# %%
store_df["Region"].value_counts()
# Out:
# Region
# West       3177
# East       2832
# Central    2315
# South      1620
# Name: count, dtype: int64

# %%
regions_info  = store_df.groupby('Region').sum().reset_index()
regions_info
# Out:
#     Region                                          Ship Mode  \
# 0  Central  Standard ClassStandard ClassStandard ClassStan...
# 1     East  Second ClassStandard ClassStandard ClassStanda...
# 2    South  Second ClassSecond ClassStandard ClassStandard...
# 3     West  Second ClassStandard ClassStandard ClassStanda...
#
#                                              Segment  \
# 0  Home OfficeHome OfficeConsumerCorporateCorpora...
# 1  ConsumerConsumerConsumerConsumerConsumerConsum...
# 2  ConsumerConsumerConsumerConsumerConsumerCorpor...
# 3  CorporateConsumerConsumerConsumerConsumerConsu...
#
#                                              Country  \
# 0  United StatesUnited StatesUnited StatesUnited ...
# 1  United StatesUnited StatesUnited StatesUnited ...
# 2  United StatesUnited StatesUnited StatesUnited ...
# 3  United StatesUnited StatesUnited StatesUnited ...
#
#                                                 City  \
# 0  Fort WorthFort WorthMadisonFremontFremontHoust...
# ...

# %% [markdown]
# Region Sales

# %%
regions_info [['Region'  , 'Sales']]
# Out:
#     Region        Sales
# 0  Central  500724.2708
# 1     East  677843.9080
# 2    South  391721.9050
# 3     West  724309.2935

# %%
Viz_Bar(regions_info.sort_values(by = ['Sales'] , ascending = False) , 'Region' , 'Sales' ,'REGION SALES')

# %%
store_df.groupby("Region")["Sales"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Sales'>

# %% [markdown]
# Region Profit

# %%
regions_info [['Region'  , 'Profit']]
# Out:
#     Region       Profit
# 0  Central   39662.0474
# 1     East   91471.0909
# 2    South   46749.4303
# 3     West  108214.9893

# %%
Viz_Bar(regions_info.sort_values(by=['Profit'] , ascending = False) , 'Region' , 'Profit' ,'REGION PROFIT')

# %%
store_df.groupby("Region")["Profit"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Profit'>

# %% [markdown]
# West & East Region has The Highest Sales & Highest Profit.

# %% [markdown]
# #### Category Analysis

# %%
store_df["Category"].value_counts()
# Out:
# Category
# Office Supplies    5986
# Furniture          2114
# Technology         1844
# Name: count, dtype: int64

# %%
category_info = store_df.groupby("Category").sum().reset_index()
category_info
# Out:
#           Category                                          Ship Mode  \
# 0        Furniture  Second ClassSecond ClassStandard ClassStandard...
# 1  Office Supplies  Second ClassStandard ClassStandard ClassStanda...
# 2       Technology  Standard ClassStandard ClassSecond ClassSecond...
#
#                                              Segment  \
# 0  ConsumerConsumerConsumerConsumerConsumerConsum...
# 1  CorporateConsumerConsumerConsumerConsumerConsu...
# 2  ConsumerConsumerConsumerConsumerCorporateHome ...
#
#                                              Country  \
# 0  United StatesUnited StatesUnited StatesUnited ...
# 1  United StatesUnited StatesUnited StatesUnited ...
# 2  United StatesUnited StatesUnited StatesUnited ...
#
#                                                 City  \
# 0  HendersonHendersonFort LauderdaleLos AngelesLo...
# 1  Los AngelesFort LauderdaleLos AngelesLos Angel...
# 2  Los AngelesLos AngelesSan FranciscoLos Angeles...
#
# ...

# %% [markdown]
# Category Sales

# %%
category_info[["Category"   ,"Sales"]]
# Out:
#           Category        Sales
# 0        Furniture  740568.6663
# 1  Office Supplies  718256.0700
# 2       Technology  835774.6410

# %%
Viz_Bar(category_info.sort_values(by=['Sales'] ,ascending=False), 'Category' , 'Sales' , 'CATEGORY SALES')

# %%
store_df.groupby("Category")["Sales"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Sales'>

# %% [markdown]
# The 3 Categories are Approximately Making The Same Amount of Sales

# %% [markdown]
# Category Profit

# %%
category_info[["Category"   ,"Profit"]]
# Out:
#           Category       Profit
# 0        Furniture   18484.9459
# 1  Office Supplies  122196.0726
# 2       Technology  145416.5394

# %%
Viz_Bar(category_info.sort_values(by=['Profit'] ,ascending=False), 'Category' , 'Profit' , 'CATEGORY PROFIT')

# %%
store_df.groupby("Category")["Profit"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Profit'>

# %% [markdown]
# Its is clearly  Observed that Technology Category Has The Highest Sales & Profit.

# %% [markdown]
# #### Sub-Category Analysis

# %%
store_df["Sub-Category"].value_counts()
# Out:
# Sub-Category
# Binders        1518
# Paper          1344
# Furnishings     954
# Phones          888
# Storage         845
# Art             793
# Accessories     773
# Chairs          615
# Appliances      466
# Labels          359
# Tables          319
# Envelopes       254
# Bookcases       226
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %%
sub_category_info = store_df.groupby("Sub-Category").sum().reset_index()
sub_category_info
# Out:
#    Sub-Category                                          Ship Mode  \
# 0   Accessories  Second ClassFirst ClassStandard ClassFirst Cla...
# 1    Appliances  Standard ClassStandard ClassStandard ClassFirs...
# 2           Art  Standard ClassSecond ClassStandard ClassStanda...
# 3       Binders  Standard ClassStandard ClassStandard ClassSeco...
# 4     Bookcases  Second ClassStandard ClassStandard ClassFirst ...
# 5        Chairs  Second ClassSecond ClassStandard ClassStandard...
# 6       Copiers  Second ClassSecond ClassStandard ClassStandard...
# 7     Envelopes  Standard ClassStandard ClassStandard ClassSeco...
# 8     Fasteners  Standard ClassSecond ClassFirst ClassStandard ...
# 9   Furnishings  Standard ClassStandard ClassFirst ClassStandar...
# 10       Labels  Second ClassStandard ClassStandard ClassStanda...
# 11     Machines  Standard ClassStandard ClassFirst ClassSecond ...
# 12        Paper  Standard ClassSecond ClassFirst ClassFirst Cla...
# ...

# %% [markdown]
# Sub-Category Sales

# %%
sub_category_info[["Sub-Category"   ,"Sales"]].sort_values(by = ['Sales'] , ascending = False).head(10)
# Out:
#    Sub-Category        Sales
# 13       Phones  329704.6780
# 5        Chairs  327777.7610
# 14      Storage  223808.4400
# 16       Tables  206965.5320
# 3       Binders  203328.8590
# 11     Machines  189238.6310
# 0   Accessories  167303.3020
# 6       Copiers  149528.0300
# 4     Bookcases  114166.9293
# 1    Appliances  107532.1610

# %%
Viz_Bar(sub_category_info.sort_values(by=['Sales'] , ascending = False), 'Sub-Category' , 'Sales' , 'TOP 10 SUB-CATEGORY SALES' , 'horizontal' ,False)

# %% [markdown]
# Its is observed That Phone Sub Category Has the Highest Sales than Copiers

# %% [markdown]
# Sub-Category Profit

# %%
sub_category_info[["Sub-Category"   ,"Profit"]].sort_values(by=["Profit"] , ascending = False).head(10)
# Out:
#    Sub-Category      Profit
# 6       Copiers  55617.8249
# 13       Phones  44493.0524
# 0   Accessories  41920.9052
# 12        Paper  33830.0381
# 3       Binders  30205.2603
# 5        Chairs  26567.1278
# 14      Storage  21287.1788
# 1    Appliances  18138.0054
# 9   Furnishings  13042.0534
# 7     Envelopes   6964.1767

# %%
Viz_Bar(sub_category_info.sort_values(by=['Profit'] , ascending = False), 'Sub-Category' , 'Profit' , 'TOP 10 PROFITABLE SUB-CATEGORY' , 'horizontal',False)

# %% [markdown]
# Its is observed That Copiers Sub Category Has the Highest Profit than Phone

# %% [markdown]
# Non Profitable Sub Categories

# %%
sub_category_info[sub_category_info['Profit']<=0]
# Out:
#    Sub-Category                                          Ship Mode  \
# 4     Bookcases  Second ClassStandard ClassStandard ClassFirst ...
# 15     Supplies  Standard ClassSecond ClassSecond ClassSame Day...
# 16       Tables  Standard ClassStandard ClassStandard ClassStan...
#
#                                               Segment  \
# 4   ConsumerConsumerHome OfficeHome OfficeHome Off...
# 15  ConsumerConsumerCorporateCorporateHome OfficeH...
# 16  ConsumerConsumerConsumerConsumerConsumerConsum...
#
#                                               Country  \
# 4   United StatesUnited StatesUnited StatesUnited ...
# 15  United StatesUnited StatesUnited StatesUnited ...
# 16  United StatesUnited StatesUnited StatesUnited ...
#
#                                                  City  \
# 4   HendersonPhiladelphiaHoustonNew York CityNew Y...
# 15  RosevilleNewarkTamaracManchesterJacksonPhoenix...
# 16  Fort LauderdaleLos AngelesOremSeattleBloomingt...
#
# ...

# %% [markdown]
# The 3 Sub Category Bookcases,Supplies and Tables are making No Profit

# %% [markdown]
# #### Category and Sub Category analysis on the basis of Quantity

# %% [markdown]
# Category Analysis With Quantity

# %%
category_info=store_df.groupby("Category").sum()[["Quantity"]].reset_index()
category_info
# Out:
#           Category  Quantity
# 0        Furniture      8010
# 1  Office Supplies     22786
# 2       Technology      6932

# %%
category_info=store_df.groupby("Category").sum()[["Quantity"]].plot.line()
category_info
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# As Office Supplies Category has the High nos of Quantity whereas Furtinure and Technology has low nos of Quantity

# %% [markdown]
# Sub-Category Analysis With Quantity

# %%
sub_category_info=store_df.groupby("Sub-Category").sum()[["Quantity"]].reset_index()
sub_category_info
# Out:
#    Sub-Category  Quantity
# 0   Accessories      2972
# 1    Appliances      1729
# 2           Art      2986
# 3       Binders      5961
# 4     Bookcases       863
# 5        Chairs      2351
# 6       Copiers       234
# 7     Envelopes       906
# 8     Fasteners       914
# 9   Furnishings      3555
# 10       Labels      1387
# 11     Machines       440
# 12        Paper      5100
# 13       Phones      3286
# 14      Storage      3156
# 15     Supplies       647
# 16       Tables      1241

# %%
sub_category_info=store_df.groupby("Sub-Category").sum()[["Quantity"]].plot.line()

# %% [markdown]
# In this Art Sub Category Has the  Highest nos of Quantity

# %% [markdown]
# #### Category and Quantity analysis on the basis of Sales and Profit

# %% [markdown]
# Relationship between Category and Quantity

# %%
pivot_table = store_df.pivot_table(index = "Category" ,columns="Quantity" ,values="Sales" , aggfunc = 'sum')
pivot_table
# Out:
# Quantity                 1            2            3            4   \
# Category
# Furniture        18491.2395   86992.9898  137170.5537   85080.7304
# Office Supplies  17217.9120   94423.8040  142528.1580   88066.8920
# Technology       17500.0630  106832.1900  140921.3940  150327.7800
#
# Quantity                  5           6           7          8           9   \
# Category
# Furniture        127640.4515  73934.1894  69861.8179  43689.608  55254.8061
# Office Supplies  136800.1150  65416.9260  74779.2920  36475.448  32039.9460
# Technology       151179.8300  67732.3260  95267.2560  37595.120  41210.8380
#
# Quantity                10        11        12         13        14
# Category
# Furniture        13437.674  7035.281  8782.848   8300.383  4896.094
# Office Supplies   3864.130  3694.867  2342.328  15894.580  4711.672
# Technology        6754.860  5042.334  3743.232   8143.226  3524.192

# %%
pivot_table.plot(kind = 'line'  ,stacked = False)
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
pivot_table2 = store_df.pivot_table(index = "Category" ,columns="Quantity" ,values="Profit" , aggfunc = 'sum')
pivot_table2
# Out:
# Quantity                1           2           3           4           5   \
# Category
# Furniture        -105.5951   2380.1588   2911.5993   1954.1496   3160.4685
# Office Supplies  3702.6374  19820.6758  29643.5100  11665.2288  20435.4165
# Technology       3825.1066  16238.0278  24305.7969  30518.4804  25907.9365
#
# Quantity                6           7          8          9         10  \
# Category
# Furniture        1750.8078  -2499.0098  3605.5416  3506.5341   772.357
# Office Supplies  3329.3982  14463.2152  2262.6256  7395.9300    99.312
# Technology       5226.5994  22322.7676  4988.6288  6785.4267  1172.488
#
# Quantity                11        12         13         14
# Category
# Furniture        1674.7973 -346.9992 -1154.6106   874.7466
# Office Supplies  1073.7760  676.0452  6441.7795  1186.5224
# Technology       1544.7938  856.0200  1061.7321   662.7348

# %%
pivot_table2.plot(kind = 'line'  ,stacked = False)
plt.ylabel("Profit")
# Out:
# Text(0, 0.5, 'Profit')

# %% [markdown]
# #### Sub-Category and Quantity analysis on the basis of Sales and Profit

# %% [markdown]
# RelationShip Between Sub-Category and Quantity

# %%
pivot_table = store_df.pivot_table(index = "Sub-Category" ,columns="Quantity" ,values="Sales" , aggfunc = 'sum')
pivot_table
# Out:
# Quantity             1           2           3           4           5   \
# Sub-Category
# Accessories   3786.6560  17699.1520  33241.8840  20321.9920  30891.1500
# Appliances    2229.0350  13838.2140  20237.3820  14077.0920  19240.1500
# Art            608.4620   3174.5000   4884.3600   3214.4880   4213.9900
# Binders       5365.2190  29605.0900  40031.3580  21250.8880  43695.5950
# Bookcases     3195.0760  14764.1978  16512.9822  11179.3464  23824.0140
# Chairs        6713.8500  40276.4240  60362.7720  40889.2200  63926.3100
# Copiers       3439.9360  16459.6520  19379.7480  42359.6960  43799.4600
# Envelopes      335.3260   3058.9760   4080.4980   1497.6720   2759.2600
# Fasteners       46.9040    254.6000    472.4340    447.9280    552.5700
# Furnishings   1994.9220  11596.1720  18877.5840  10839.2800  17858.8500
# Labels         202.8300   1517.4280   1842.4320   1162.1280   2178.7200
# Machines      1834.2770  26233.2300  25985.6580  38283.7720  25218.9300
# ...

# %%
pivot_table.plot(kind = 'line'  ,stacked = False)
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
pivot_table2 = store_df.pivot_table(index = "Sub-Category" ,columns="Quantity" ,values="Profit" , aggfunc = 'sum')
pivot_table2
# Out:
# Quantity             1          2           3           4           5   \
# Sub-Category
# Accessories    963.2807  4771.9650   8037.8085   6025.9948   7463.9455
# Appliances     313.3486  1420.1100   4325.4270   2299.1984   2475.3975
# Art            144.7241   730.0378   1180.5768    747.7932   1064.5510
# Binders       1680.3962  8962.5910  11590.1523   -479.3136   5314.9420
# Bookcases      -73.4031   325.1232   -374.7063   -725.8488    366.3105
# Chairs         633.3828  2106.6792   4215.8811   3141.9436   3978.0355
# Copiers       1378.9746  5217.8960   7835.9163  13979.9132  17004.8235
# Envelopes      143.9781  1356.3826   1727.3238    626.6224   1195.0685
# Fasteners       17.3471    81.1824    144.0456    148.4296    188.8480
# Furnishings    356.8239  1566.9302   2850.5361   1317.6152   1009.0285
# Labels          83.2672   685.9500    817.3302    484.5368   1003.6970
# Machines        45.0944   545.5482   -787.8849   3921.4996  -4943.2790
# ...

# %%
pivot_table2.plot(kind = 'line'  ,stacked = False)
plt.ylabel("Profit")
# Out:
# Text(0, 0.5, 'Profit')

# %% [markdown]
# #### Sales and Profit Conclusion

# %% [markdown]
# Sales and Profit Ratio

# %%
sales_profit_by_segment = store_df.groupby('Segment').agg({'Sales': 'sum', 'Profit': 'sum'}).reset_index()
sales_profit_by_segment['Sales_to_Profit_Ratio'] = sales_profit_by_segment['Sales'] / sales_profit_by_segment['Profit']
print(sales_profit_by_segment[['Segment', 'Sales_to_Profit_Ratio']])
# Out:
#        Segment  Sales_to_Profit_Ratio
# 0     Consumer               8.656276
# 1    Corporate               7.681006
# 2  Home Office               7.124215

# %%
sales_profit_by_segment.groupby("Sales")["Profit"].sum().plot.line()
# Out:
# <Axes: xlabel='Sales'>

# %% [markdown]
# #### Impact Of Discount on Sales and Profit

# %%
discounts_info = store_df.groupby("Discount").sum()[[ 'Sales' , 'Profit']].reset_index()
discounts_info
# Out:
#     Discount         Sales       Profit
# 0       0.00  1.086946e+06  320696.8859
# 1       0.10  5.436935e+04    9029.1770
# 2       0.15  2.719902e+04    1448.5973
# 3       0.20  7.636026e+05   90275.6701
# 4       0.30  1.029453e+05  -10357.2186
# 5       0.32  1.449346e+04   -2391.1377
# 6       0.40  1.164178e+05  -23057.0504
# 7       0.45  5.484974e+03   -2493.1111
# 8       0.50  5.891854e+04  -20506.4281
# 9       0.60  6.644700e+03   -5944.6552
# 10      0.70  4.062028e+04  -40075.3569
# 11      0.80  1.695726e+04  -30527.8144

# %% [markdown]
# Sales and discount analysis of data

# %%
discounts_info = store_df.groupby("Discount")["Sales"].sum().plot.line()

# %% [markdown]
# We Observe that Discounts after 20% Will Reduce The Store Sales.

# %% [markdown]
# Profit and discount analysis of data

# %%
discounts_info = store_df.groupby("Discount")["Profit"].sum().plot.line()

# %% [markdown]
# We Conclude That Discounts More Than 20% Results a Negative Profit , Therfore Our Discounts Should'nt Be More Than 20% In Order to Maintain Our Sales & Profit .

# %% [markdown]
# #### Sales & Profit Conclusion Over Time

# %% [markdown]
# Sales and Profit Dataset

# %%
sales_data= {
    "Order Date": ["1/2014","2/2014","3/2014","4/2014","5/2014","6/2014","7/2014","8/2014","9/2014","10/2014",
    "11/2014","12/2014","1/2015","2/2015","3/2015","4/2015","5/2015","6/2015","7/2015","8/2015",
    "9/2015","10/2015","11/2015","12/2015","1/2016","2/2016","3/2016","4/2016","5/2016",
    "6/2016","7/2016","8/2016","9/2016","10/2016","11/2016","12/2016","1/2017","2/2017","3/2017",
    "4/2017","5/2017","6/2017","7/2017","8/2017","9/2017","10/2017","11/2017","12/2017"
    ],
    "Sales": [ 14236.895 ,   4519.892 ,  55691.009 ,  28295.345 ,  23648.287 ,
        34595.1276,  33946.393 ,  27909.4685,  81777.3508,  31453.393 ,
        78628.7167,  69545.6205,  18174.0756,  11951.411 ,  38726.252 ,
        34195.2085,  30131.6865,  24797.292 ,  28765.325 ,  36898.3322,
        64595.918 ,  31404.9235,  75972.5635,  74919.5212,  18542.491 ,
        22978.815 ,  51715.875 ,  38750.039 ,  56987.728 ,  40344.534 ,
        39261.963 ,  31115.3743,  73410.0249,  59687.745 ,  79411.9658,
        96999.043 ,  43971.374 ,  20301.1334,  58872.3528,  36521.5361,
        44261.1102,  52981.7257,  45264.416 ,  63120.888 ,  87866.652 ,
        77776.9232, 118447.825 ,  83829.3188],
    
    "Profit" :[ 2450.1907,   862.3084,   498.7299,  3488.8352,  2738.7096,
        4976.5244,  -841.4826,  5318.105 ,  8328.0994,  3448.2573,
        9292.1269,  8983.5699, -3281.007 ,  2813.8508,  9732.0978,
        4187.4962,  4667.869 ,  3335.5572,  3288.6483,  5355.8084,
        8209.1627,  2817.366 , 12474.7884,  8016.9659,  2824.8233,
        5004.5795,  3611.968 ,  2977.8149,  8662.1464,  4750.3781,
        4432.8779,  2062.0693,  9328.6576, 16243.1425,  4011.4075,
       17885.3093,  7140.4391,  1613.872 , 14751.8915,   933.29  ,
        6342.5828,  8223.3357,  6952.6212,  9040.9557, 10991.5556,
        9275.2755,  9690.1037,  8483.3468]

}

# %%
sales_data=pd.DataFrame(sales_data)
sales_data
# Out:
#    Order Date        Sales      Profit
# 0      1/2014   14236.8950   2450.1907
# 1      2/2014    4519.8920    862.3084
# 2      3/2014   55691.0090    498.7299
# 3      4/2014   28295.3450   3488.8352
# 4      5/2014   23648.2870   2738.7096
# 5      6/2014   34595.1276   4976.5244
# 6      7/2014   33946.3930   -841.4826
# 7      8/2014   27909.4685   5318.1050
# 8      9/2014   81777.3508   8328.0994
# 9     10/2014   31453.3930   3448.2573
# 10    11/2014   78628.7167   9292.1269
# 11    12/2014   69545.6205   8983.5699
# 12     1/2015   18174.0756  -3281.0070
# 13     2/2015   11951.4110   2813.8508
# 14     3/2015   38726.2520   9732.0978
# 15     4/2015   34195.2085   4187.4962
# 16     5/2015   30131.6865   4667.8690
# 17     6/2015   24797.2920   3335.5572
# 18     7/2015   28765.3250   3288.6483
# 19     8/2015   36898.3322   5355.8084
# 20     9/2015   64595.9180   8209.1627
# 21    10/2015   31404.9235   2817.3660
# 22    11/2015   75972.5635  12474.7884
# ...

# %%
sales_data['Order Date'] = sales_data['Order Date'].astype('datetime64[ns]')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7908\3967398841.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sales_data['Order Date'] = sales_data['Order Date'].astype('datetime64[ns]')

# %%
print(sales_data['Order Date'][0])
print(sales_data['Order Date'][0].year , " " , sales_data['Order Date'][0].month ," " ,sales_data['Order Date'][0].day)
# Out:
# 2014-01-01 00:00:00
# 2014   1   1

# %% [markdown]
# Monthly dataset of Sales and Profit

# %%
monthly_data = sales_data.groupby(['Order Date'], as_index=False).sum()[['Order Date' , 'Sales' , 'Profit']]

# Set the Order Date column as the index of the dataframe
monthly_data = monthly_data.set_index('Order Date')

# Resample the data into monthly intervals
monthly_data = monthly_data.resample('M').sum()

monthly_data.reset_index(inplace=True)
# Transforming Column For Clarification
monthly_data["Order Date"] = [str(k.month)+'/'+str(k.year) for k in monthly_data['Order Date'] ]
monthly_data.rename(columns = {"Order Date":'Month'}, inplace = True)
monthly_data = monthly_data.set_index('Month')


monthly_data
# Out:
#                Sales      Profit
# Month
# 1/2014    14236.8950   2450.1907
# 2/2014     4519.8920    862.3084
# 3/2014    55691.0090    498.7299
# 4/2014    28295.3450   3488.8352
# 5/2014    23648.2870   2738.7096
# 6/2014    34595.1276   4976.5244
# 7/2014    33946.3930   -841.4826
# 8/2014    27909.4685   5318.1050
# 9/2014    81777.3508   8328.0994
# 10/2014   31453.3930   3448.2573
# 11/2014   78628.7167   9292.1269
# 12/2014   69545.6205   8983.5699
# 1/2015    18174.0756  -3281.0070
# 2/2015    11951.4110   2813.8508
# 3/2015    38726.2520   9732.0978
# 4/2015    34195.2085   4187.4962
# 5/2015    30131.6865   4667.8690
# 6/2015    24797.2920   3335.5572
# 7/2015    28765.3250   3288.6483
# 8/2015    36898.3322   5355.8084
# 9/2015    64595.9180   8209.1627
# 10/2015   31404.9235   2817.3660
# 11/2015   75972.5635  12474.7884
# 12/2015   74919.5212   8016.9659
# 1/2016    18542.4910   2824.8233
# 2/2016    22978.8150   5004.5795
# 3/2016    51715.8750   3611.9680
# ...

# %% [markdown]
# Monthly Sales From 1/2014 to 12/2017

# %%
plt.figure(figsize=(25,8))
plt.plot(monthly_data['Sales'])
plt.axvline(monthly_data.sort_values(by = ["Sales"] , ascending = False).reset_index()['Month'][0], color='black')

plt.xlabel("Order Date")
plt.ylabel("Sales")
plt.title("MONTHLY SALES")
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Monthly Profit From 1/2014 to 12/2017

# %%
# Plot
plt.figure(figsize=(25,8))
plt.plot(monthly_data['Profit'])
plt.axvline(monthly_data.sort_values(by = ["Profit"] , ascending = False).reset_index()['Month'][0], color='black')

plt.xlabel("Month/Year")
plt.ylabel("Sales")
plt.title("MONTHLY PROFIT")
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Yearly Sales and Profit dataset

# %%
yearly_data = sales_data.groupby(['Order Date'], as_index=False).sum()[['Order Date' , 'Sales' , 'Profit']]

# Set the Order Date column as the index of the dataframe
yearly_data = yearly_data.set_index('Order Date')

# Resample the data into yearly intervals
yearly_data = yearly_data.resample('Y').sum()

yearly_data.reset_index(inplace=True)
# Transforming Column For Clarification
yearly_data["Order Date"] = [str(k.year) for k in yearly_data['Order Date'] ]
yearly_data.rename(columns = {"Order Date":'Year'}, inplace = True)
yearly_data = yearly_data.set_index('Year')


yearly_data
# Out:
#             Sales      Profit
# Year
# 2014  484247.4981  49543.9741
# 2015  470532.5090  61618.6037
# 2016  609205.5980  81795.1743
# 2017  733215.2552  93439.2696

# %% [markdown]
# Yearly Sales from 2014 to 2017

# %%
# Plot
plt.figure(figsize=(25,8))
plt.plot(yearly_data['Sales'])
plt.xlabel("Year")
plt.ylabel("Sales")
plt.title("YEARLY SALES")
plt.show()

# %% [markdown]
# Yearly Profit from 2014 to 2017

# %%
# Plot
plt.figure(figsize=(25,8))
plt.plot(yearly_data['Profit'])
plt.xlabel("Year")
plt.ylabel("Profit")
plt.title("YEARLY PROFIT")
plt.show()

# %% [markdown]
# Its Observed That Sales & Profit are increasing through years which is a good indication.

# %% [markdown]
# ### Summary

# %% [markdown]
# We have Completely analysis the SuperStore DataSet
